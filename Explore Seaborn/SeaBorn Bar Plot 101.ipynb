# %%
# ================================================
#                Bar Plot in Seaborn
# ================================================
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x = df['island'], y = df['bill_length_mm'])
# Out:
# <AxesSubplot: xlabel='island', ylabel='bill_length_mm'>

# %%
sns.barplot(x = "island", y = "bill_length_mm", data = df, hue = "sex")
plt.show()

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1)
plt.show()

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1,
    hue_order=["Female", "Male"]
    )
plt.show()

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\3755445341.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\170423729.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(data = df, x = "bill_length_mm", y = "bill_depth_mm", orient="v")
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.barplot(data = df, x = "bill_length_mm", y = "bill_depth_mm", orient="h")
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    color = 'g'
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\2273136722.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    color='r'
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\2384910095.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    palette='icefire'
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\3734333390.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    palette='icefire',
    saturation=0.5,
    errcolor='r',
    errwidth=15,
    capsize=0.5
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\2221778327.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    palette='icefire',
    saturation=0.5,
    errcolor='r',
    errwidth=15,
    capsize=0.5,
    dodge=False
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\3942017412.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    palette='icefire',
    saturation=0.5,
    errcolor='r',
    errwidth=15,
    capsize=0.5, 
    alpha = 0.5
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\2813099956.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",

# %%
sns.set(style="darkgrid")
order_1 = ["Dream", "Biscoe", "Torgersen"]
sns.barplot(x = "island", y = "bill_length_mm", 
    data = df, hue = "sex", order=order_1, hue_order=["Female", "Male"],
    ci = 20,
    n_boot=50,
    palette='icefire',
    saturation=0.5,
    errcolor='r',
    errwidth=15,
    capsize=0.5
    )
plt.show()
# Out:
# C:\Users\Internee\AppData\Local\Temp\ipykernel_7300\4087156463.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 20)` for the same effect.
#
#   sns.barplot(x = "island", y = "bill_length_mm",
